# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
gp = pd.read_csv("./googleplaystore.csv")
gp
# Out:
#                                                      App             Category  \
# 0         Photo Editor & Candy Camera & Grid & ScrapBook       ART_AND_DESIGN
# 1                                    Coloring book moana       ART_AND_DESIGN
# 2      U Launcher Lite – FREE Live Cool Themes, Hide ...       ART_AND_DESIGN
# 3                                  Sketch - Draw & Paint       ART_AND_DESIGN
# 4                  Pixel Draw - Number Art Coloring Book       ART_AND_DESIGN
# 5                             Paper flowers instructions       ART_AND_DESIGN
# 6                Smoke Effect Photo Maker - Smoke Editor       ART_AND_DESIGN
# 7                                       Infinite Painter       ART_AND_DESIGN
# 8                                   Garden Coloring Book       ART_AND_DESIGN
# 9                          Kids Paint Free - Drawing Fun       ART_AND_DESIGN
# 10                               Text on Photo - Fonteee       ART_AND_DESIGN
# ...

# %%
gp.shape
# Out:
# (10841, 13)

# %%
data = gp.drop_duplicates(subset='App', keep='first')

# %%
data.shape
# Out:
# (9660, 13)

# %%
data.loc[10472]
# Out:
# App               Life Made WI-Fi Touchscreen Photo Frame
# Category                                              1.9
# Rating                                                 19
# Reviews                                              3.0M
# Size                                               1,000+
# Installs                                             Free
# Type                                                    0
# Price                                            Everyone
# Content Rating                                        NaN
# Genres                                  February 11, 2018
# Last Updated                                       1.0.19
# Current Ver                                    4.0 and up
# Android Ver                                           NaN
# Name: 10472, dtype: object

# %%
data = data.drop([10472])

# %%
data.shape
# Out:
# (9659, 13)

# %%
c = data['Category']

# %%
c.shape
# Out:
# (9659,)

# %%
cnum = pd.get_dummies(c)

# %%
cnum.shape
# Out:
# (9659, 33)

# %%
from sklearn.decomposition import PCA

# %%
pca = PCA(n_components=1)
c1 = pca.fit_transform(cnum)

# %%
c1.shape
# Out:
# (9659, 1)

# %%
c2 = pd.DataFrame(c1,columns=['category'])

# %%
c2.shape
# Out:
# (9659, 1)

# %%
z = pd.concat([c,c2],axis=1)

# %%
z.shape
# Out:
# (10798, 2)

# %%
z.head()
# Out:
#          Category  category
# 0  ART_AND_DESIGN -0.137103
# 1  ART_AND_DESIGN -0.137103
# 2  ART_AND_DESIGN -0.137103
# 3  ART_AND_DESIGN -0.137103
# 4  ART_AND_DESIGN -0.137103

# %%
x = pd.concat([data,c2],axis=1,ignore_index=True)

# %%
x.head()
# Out:
#                                                   0               1    2   \
# 0     Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN  4.1
# 1                                Coloring book moana  ART_AND_DESIGN  3.9
# 2  U Launcher Lite – FREE Live Cool Themes, Hide ...  ART_AND_DESIGN  4.7
# 3                              Sketch - Draw & Paint  ART_AND_DESIGN  4.5
# 4              Pixel Draw - Number Art Coloring Book  ART_AND_DESIGN  4.3
#
#        3     4            5     6  7         8                          9   \
# 0     159   19M      10,000+  Free  0  Everyone               Art & Design
# 1     967   14M     500,000+  Free  0  Everyone  Art & Design;Pretend Play
# 2   87510  8.7M   5,000,000+  Free  0  Everyone               Art & Design
# 3  215644   25M  50,000,000+  Free  0      Teen               Art & Design
# 4     967  2.8M     100,000+  Free  0  Everyone    Art & Design;Creativity
#
#                  10                  11            12        13
# ...

# %%
x.shape
# Out:
# (10798, 14)

# %%
x.isna().sum()
# Out:
# 0     1139
# 1     1139
# 2     2602
# 3     1139
# 4     1139
# 5     1139
# 6     1140
# 7     1139
# 8     1139
# 9     1139
# 10    1139
# 11    1147
# 12    1141
# 13    1139
# dtype: int64

# %%
# y = x[x['category'].isnull()]
# y

# %%
data.loc[10811]
# Out:
# App                     FR Plus 1.6
# Category          AUTO_AND_VEHICLES
# Rating                          NaN
# Reviews                           4
# Size                           3.9M
# Installs                       100+
# Type                           Free
# Price                             0
# Content Rating             Everyone
# Genres              Auto & Vehicles
# Last Updated          July 24, 2018
# Current Ver                   1.3.6
# Android Ver             4.4W and up
# Name: 10811, dtype: object

# %%
dup = gp[gp.duplicated(['App'])]
dup
# Out:
#                                                      App            Category  \
# 229                         Quick PDF Scanner + OCR FREE            BUSINESS
# 236                                                  Box            BUSINESS
# 239                                   Google My Business            BUSINESS
# 256                                  ZOOM Cloud Meetings            BUSINESS
# 261                            join.me - Simple Meetings            BUSINESS
# 265                                                  Box            BUSINESS
# 266                                             Zenefits            BUSINESS
# 267                                           Google Ads            BUSINESS
# 268                                   Google My Business            BUSINESS
# 269                                                Slack            BUSINESS
# 270                                   FreshBooks Classic            BUSINESS
# ...

# %%
dup.shape
# Out:
# (1181, 13)

# %%
df = data.reset_index(drop=True)

# %%
df1 = pd.concat([df,c2],axis=1)
df1.shape
# Out:
# (9659, 14)

# %%
s_count = pd.Series(df['Size'])
s_count.value_counts()
# Out:
# Varies with device    1227
# 11M                    182
# 12M                    181
# 14M                    177
# 13M                    177
# 15M                    163
# 17M                    146
# 26M                    142
# 16M                    137
# 19M                    130
# 10M                    128
# 21M                    124
# 20M                    122
# 25M                    119
# 18M                    119
# 24M                    117
# 22M                    104
# 23M                    104
# 29M                     92
# 27M                     91
# 28M                     90
# 30M                     83
# 3.3M                    73
# 33M                     71
# 2.5M                    68
# 2.3M                    68
# 2.9M                    67
# 37M                     67
# 31M                     67
# 2.8M                    65
#                       ...
# 499k                     1
# 655k                     1
# 601k                     1
# ...

# %%
size =  pd.Series(df['Size'])

# %%
kb = []
for i in size:
    if 'k' in i:
        i=float(i.replace('k',''))
        j = i/1000
        kb.append(j)
    elif 'M' in i:
        i = float(i.replace('M',''))
        kb.append(i)
    else:
        kb.append(i)        
print(kb)
# Out:
# [19.0, 14.0, 8.7, 25.0, 2.8, 5.6, 19.0, 29.0, 33.0, 3.1, 28.0, 12.0, 20.0, 21.0, 37.0, 2.7, 5.5, 17.0, 39.0, 31.0, 14.0, 12.0, 4.2, 7.0, 23.0, 6.0, 25.0, 6.1, 4.6, 4.2, 9.2, 5.2, 11.0, 11.0, 4.2, 9.2, 24.0, 'Varies with device', 11.0, 9.4, 15.0, 10.0, 'Varies with device', 1.2, 12.0, 24.0, 26.0, 8.0, 7.9, 25.0, 56.0, 57.0, 'Varies with device', 35.0, 33.0, 33.0, 5.6, 54.0, 0.201, 3.6, 5.7, 17.0, 8.6, 2.4, 27.0, 2.7, 2.5, 'Varies with device', 'Varies with device', 7.0, 35.0, 16.0, 16.0, 'Varies with device', 17.0, 3.4, 8.9, 3.9, 2.9, 38.0, 32.0, 37.0, 15.0, 5.4, 18.0, 'Varies with device', 38.0, 1.1, 'Varies with device', 'Varies with device', 7.9, 35.0, 'Varies with device', 17.0, 19.0, 14.0, 2.2, 4.5, 17.0, 14.0, 9.8, 21.0, 'Varies with device', 52.0, 14.0, 25.0, 9.0, 'Varies with device', 12.0, 'Varies with device', 35.0, 6.7, 30.0, 5.7, 2.9, 17.0, 2.9, 'Varies with device', 'Varies with device', 2.6, 4.2, 7.1, 57.0, 3.7, 22.0, 24.0, 7.4, 21.0, 3.4, 2.9, 3.1, 6.4, 3.2, 8.2, 9.9, 2
# ...

# %%
mb = []
for i in size:
    if 'M' in i:
        i=float(i.replace('M',''))
        j = i*1000
        mb.append(j)
    elif 'k' in i:
        i = float(i.replace('k',''))
        mb.append(i)
    else:
        mb.append(i)
Mb = pd.DataFrame(mb)
Mb
# Out:
#                        0
# 0                  19000
# 1                  14000
# 2                   8700
# 3                  25000
# 4                   2800
# 5                   5600
# 6                  19000
# 7                  29000
# 8                  33000
# 9                   3100
# 10                 28000
# 11                 12000
# 12                 20000
# 13                 21000
# 14                 37000
# 15                  2700
# 16                  5500
# 17                 17000
# 18                 39000
# 19                 31000
# 20                 14000
# 21                 12000
# 22                  4200
# 23                  7000
# 24                 23000
# 25                  6000
# 26                 25000
# 27                  6100
# 28                  4600
# 29                  4200
# ...                  ...
# 9629                3900
# 9630               13000
# 9631                2700
# 9632               31000
# 9633                4900
# ...

# %%
Mb.loc[9651]
# Out:
# 0    619
# Name: 9651, dtype: object
