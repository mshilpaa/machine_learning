# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
data_set = pd.read_csv("./BlackFriday.csv")

# %%
data_set
# Out:
#         User_ID Product_ID Gender    Age  Occupation City_Category  \
# 0       1000001  P00069042      F   0-17          10             A
# 1       1000001  P00248942      F   0-17          10             A
# 2       1000001  P00087842      F   0-17          10             A
# 3       1000001  P00085442      F   0-17          10             A
# 4       1000002  P00285442      M    55+          16             C
# 5       1000003  P00193542      M  26-35          15             A
# 6       1000004  P00184942      M  46-50           7             B
# 7       1000004  P00346142      M  46-50           7             B
# 8       1000004   P0097242      M  46-50           7             B
# 9       1000005  P00274942      M  26-35          20             A
# 10      1000005  P00251242      M  26-35          20             A
# 11      1000005  P00014542      M  26-35          20             A
# 12      1000005  P00031342      M  26-35          20             A
# ...

# %%
data_set.shape
# Out:
# (537577, 12)

# %%
x.unique()
# Out:
# array(['0-17', '55+', '26-35', '46-50', '51-55', '36-45', '18-25'],
#       dtype=object)

# %%
age = []
Age = data_set['Age'] 
for i in range(len(Age)):
    if Age[i]=='0-17':
        age.append(1)
    elif Age[i]=='55+':
        age.append(2)
    elif Age[i]=='26-35':
        age.append(3)
    elif Age[i]=='46-50':
        age.append(4)
    elif Age[i]=='51-55':
        age.append(5)
    elif Age[i]=='36-45':
        age.append(6)
    else:
        age.append(7)

# %%
len(age)
# Out:
# 537577

# %%
age1 = pd.DataFrame(age,columns=['age'])
age1.head()
# Out:
#    age
# 0    1
# 1    1
# 2    1
# 3    1
# 4    2

# %%
x = age1["age"]
y = data_set["Purchase"]
plt.plot(x,y,'r.')

# %%
x = data_set['Marital_Status']
y = data_set["Purchase"]
plt.plot(x,y,'r.')

# %%
x = data_set['Occupation']
y = data_set["Purchase"]
plt.plot(x,y,'r.')

# %%
target = data_set['Purchase']

x = age1["age"] 
y = target[x==0]
a = x[x==0] # 1 is the value to be found 
b = x[x==1]
c = x[x==2]
d = x[x==3]
e = x[x==4]
f = x[x==5]
g = x[x==6]
h = x[x==7]
y
# Out:
# Series([], Name: Purchase, dtype: int64)

# %%
 plt.scatter(featureset[0], featureset[1], marker='.', color=color, s=50)
